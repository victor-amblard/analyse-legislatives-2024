# %%
import pandas as pd
import numpy as np
from scipy.stats import dirichlet
from pathlib import Path
import geopandas as gpd

DATA_DIR = Path().resolve().joinpath("../data/")
RESULTS_DIR = DATA_DIR.joinpath("legislatives2022")

# %%
raw_data = pd.read_excel(
    RESULTS_DIR.joinpath(
        "resultats-par-niveau-cirlg-t1-france-entiere.xlsx"
    )
)
raw_data.head()
# Out:
#   Code du département Libellé du département  Code de la circonscription  \
# 0                  01                    Ain                           1
# 1                  01                    Ain                           2
# 2                  01                    Ain                           3
# 3                  01                    Ain                           4
# 4                  01                    Ain                           5
#
#   Libellé de la circonscription Etat saisie  Inscrits  Abstentions  % Abs/Ins  \
# 0          1ère circonscription     Complet     86187        43652      50.65
# 1          2ème circonscription     Complet     99953        50270      50.29
# 2          3ème circonscription     Complet     82204        45946      55.89
# 3          4ème circonscription     Complet     94897        49258      51.91
# 4          5ème circonscription     Complet     77456        40382      52.14
#
# ...

# %%
 & alt.Chart(
    full_results
).mark_boxplot().encode(
    x=alt.X("GroupPol:N").title("Ensemble politique"),
    y=alt.Y("value:Q").title("Nombre de voix estimé"),
).add_selection(selector).transform_filter(selector).properties(
    title="Résultats des simulations sur la circonscription 8501"
)
